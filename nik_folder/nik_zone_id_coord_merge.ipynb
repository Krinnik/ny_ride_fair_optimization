# %%
import pandas as pd
import ast

# %% [markdown]
# * this needs to be integrated into ml utils 2

# %%
# read in zone id with coordinates df
coords_df = pd.read_csv('../Resources/zone_coords_ids.csv')
coords_df['coords'] = coords_df['coords'].apply(ast.literal_eval)
coords_df[['latitude', 'longitude']] = pd.DataFrame(coords_df['coords'].tolist(), index=coords_df.index)
coords_df = coords_df[['LocationID', 'Zone', 'Borough', 'latitude', 'longitude']]
coords_df.head()
# Out:
#    LocationID                     Zone        Borough   latitude  longitude
# 0           1           Newark Airport            EWR  40.689064 -74.177255
# 1           2              Jamaica Bay         Queens  40.603994 -73.835412
# 2           3  Allerton/Pelham Gardens          Bronx  40.865430 -73.867365
# 3           4            Alphabet City      Manhattan  40.725102 -73.979583
# 4           5            Arden Heights  Staten Island  40.563700 -74.191603

# %%
# read in model_df with PU and DO Ids
results = pd.read_parquet('Resources/model_df_2.parquet')

results.columns = results.columns.str.replace('(', '').str.replace("'", "").str.replace(',', '').str.replace(')', '')

results.head()
# Out:
#    second_of_day  day_of_year  weekend  holiday  morning_rush  evening rush  \
# 0              5            1    False        1             0             0
# 1              9            1    False        1             0             0
# 2             33            1    False        1             0             0
# 3             38            1    False        1             0             0
# 4             42            1    False        1             0             0
#
#    PULocationID  DOLocationID  prcp  temp  distance  durationsec   fare  \
# 0           132            41   0.0  42.8     18.85       1599.0  70.00
# 1             3            51   0.0  42.8      2.47        785.0  14.59
# 2           145           112   0.0  42.8      2.02        474.0  20.62
# 3            16            73   0.0  42.8      2.47        459.0  23.20
# 4           164           161   0.0  42.8      1.06        335.0   7.90
#
#    tolls  airport  congestion  total  class
# 0   6.94     1.75         0.0  95.88      0
# 1   0.00     0.00         0.0  14.59      1
# 2   0.00     0.00         0.0  20.62      2
# 3   0.00     0.00         0.0  23.20      2
# 4   0.00     0.00         2.5  15.48      0

# %%
# define pickup and drop off coords and merge with results
pickup_coords = coords_df[['LocationID', 'latitude', 'longitude']].copy()
pickup_coords.rename(columns={'LocationID': 'PULocationID',
                                'latitude': 'PUy',  
                                'longitude': 'PUx'},  
                      inplace=True)

results_with_pu = pd.merge(results, pickup_coords, on='PULocationID', how='left')


dropoff_coords = coords_df[['LocationID', 'latitude', 'longitude']].copy()
dropoff_coords.rename(columns={'LocationID': 'DOLocationID',
                                'latitude': 'DOy',
                                'longitude': 'DOx'},
                       inplace=True)

results_with_coords = pd.merge(results_with_pu, dropoff_coords, on='DOLocationID', how='left')


results_with_coords.head()
# Out:
#    second_of_day  day_of_year  weekend  holiday  morning_rush  evening rush  \
# 0              5            1    False        1             0             0
# 1              9            1    False        1             0             0
# 2             33            1    False        1             0             0
# 3             38            1    False        1             0             0
# 4             42            1    False        1             0             0
#
#    PULocationID  DOLocationID  prcp  temp  ...   fare  tolls  airport  \
# 0           132            41   0.0  42.8  ...  70.00   6.94     1.75
# 1             3            51   0.0  42.8  ...  14.59   0.00     0.00
# 2           145           112   0.0  42.8  ...  20.62   0.00     0.00
# 3            16            73   0.0  42.8  ...  23.20   0.00     0.00
# 4           164           161   0.0  42.8  ...   7.90   0.00     0.00
#
#    congestion  total  class        PUy        PUx        DOy        DOx
# 0         0.0  95.88      0  40.642948 -73.779373  40.808900 -73.948200
# 1         0.0  14.59      1  40.865430 -73.867365  40.873889 -73.829444
# 2         0.0  20.62      2  40.741509 -73.956975  40.723713 -73.950971
# 3         0.0  23.20      2  40.763120 -73.770745  40.757537 -73.784305
# 4         2.5  15.48      0  40.749842 -73.984251  40.765064 -73.985319
#
# [5 rows x 22 columns]

# %%
results_with_coords.columns
# Out:
# Index(['second_of_day', 'day_of_year', 'weekend', 'holiday', 'morning_rush',
#        'evening rush', 'PULocationID', 'DOLocationID', 'prcp', 'temp',
#        'distance', 'durationsec', 'fare', 'tolls', 'airport', 'congestion',
#        'total', 'class', 'PUy', 'PUx', 'DOy', 'DOx'],
#       dtype='object')

# %%
# reorganize columns
results_with_coords = results_with_coords [['second_of_day', 'day_of_year', 'weekend', 'holiday', 'morning_rush',
       'evening rush', 'PULocationID', 'PUy', 'PUx', 'DOLocationID', 'DOy', 'DOx', 'prcp', 'temp',
       'distance', 'durationsec', 'fare', 'tolls', 'airport', 'congestion',
       'total', 'class']]

results_with_coords
# Out:
#          second_of_day  day_of_year  weekend  holiday  morning_rush  \
# 0                    5            1    False        1             0
# 1                    9            1    False        1             0
# 2                   33            1    False        1             0
# 3                   38            1    False        1             0
# 4                   42            1    False        1             0
# ...                ...          ...      ...      ...           ...
# 5971769          85846          366    False        0             0
# 5971770          85864          366    False        0             0
# 5971771          85870          366    False        0             0
# 5971772          86042          366    False        0             0
# 5971773          86273          366    False        0             0
#
#          evening rush  PULocationID        PUy        PUx  DOLocationID  ...  \
# 0                   0           132  40.642948 -73.779373            41  ...
# 1                   0             3  40.865430 -73.867365            51  ...
# 2                   0           145  40.741509 -73.956975           112  ...
# 3                   0            16  40.763120 -73.770745            73  ...
# 4                   0           164  40.749842 -73.984251           161  ...
# ...               ...           ...        ...        ...           ...  ...
# 5971769             0            58  40.839167 -73.819722           213  ...
# 5971770             0           189  40.677871 -73.968473            62  ...
# 5971771             0            79  40.729269 -73.987361            79  ...
# 5971772             0           180  40.676770 -73.843746            63  ...
# 5971773             0           211  40.722880 -73.998750           211  ...
#
#          prcp   temp  distance  durationsec   fare  tolls  airport  \
# 0         0.0  42.80     18.85       1599.0  70.00   6.94     1.75
# 1         0.0  42.80      2.47        785.0  14.59   0.00     0.00
# 2         0.0  42.80      2.02        474.0  20.62   0.00     0.00
# 3         0.0  42.80      2.47        459.0  23.20   0.00     0.00
# 4         0.0  42.80      1.06        335.0   7.90   0.00     0.00
# ...       ...    ...       ...          ...    ...    ...      ...
# 5971769   0.0  48.02      2.48        534.0  14.38   0.00     0.00
# 5971770   0.0  48.02      1.58        488.0  15.01   0.00     0.00
# 5971771   0.0  48.02      0.60        256.0   5.80   0.00     0.00
# 5971772   0.0  48.02      1.36        266.0   8.92   0.00     0.00
# 5971773   0.0  48.02      0.04         60.0   3.00   0.00     0.00
#
#          congestion  total  class
# 0               0.0  95.88      0
# 1               0.0  14.59      1
# 2               0.0  20.62      2
# 3               0.0  23.20      2
# 4               2.5  15.48      0
# ...             ...    ...    ...
# 5971769         0.0  14.38      2
# 5971770         0.0  15.01      2
# 5971771         2.5  10.80      0
# 5971772         0.0   8.92      1
# 5971773         2.5   8.00      0
#
# [5971774 rows x 22 columns]

# %%
# save results with pu and do coords
results_with_coords.to_parquet('../Resources/model_coords_df.parquet')
